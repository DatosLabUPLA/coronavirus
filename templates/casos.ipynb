# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.minsal.cl/nuevo-coronavirus-2019-ncov/casos-confirmados-en-chile-covid-19/'

headers = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:83.0) Gecko/20100101 Firefox/83.0"
}

r = requests.get('https://www.minsal.cl/nuevo-coronavirus-2019-ncov/casos-confirmados-en-chile-covid-19/')
soup = BeautifulSoup(r.text,'html.parser')
tabla = soup.find('table')
df = pd.read_html(str(tabla),skiprows=1)[0]
df.index = df[0]
columns = list(df.iloc[0])
df.columns = columns
df = df.iloc[1:]
df = df[columns[1:]]
df
# Out:
#                    Casos confirmados acumulados Casos nuevos totales  \
# 0
# Arica y Parinacota                       18.473                   96
# Tarapacá                                 30.908                  140
# Antofagasta                              45.586                  177
# Atacama                                  15.652                  113
# Coquimbo                                 29.117                  202
# Valparaíso                               74.708                  621
# RM                                      453.350                2.278
# O’Higgins                                42.620                  347
# Maule                                    60.821                  550
# Ñuble                                    23.410                  170
# Biobío                                  104.655                  675
# Araucanía                                61.173                  505
# Los Ríos                                 30.418                  157
# Los Lagos                                64.458                  240
# Aysén                                     3.827                   36
# Magallanes                               23.698                   65
# Desconocida                                  46                    0
# Total                                 1.082.920                6.372
#
#                    Casos nuevos con síntomas Casos nuevos sin síntomas  \
# 0
# Arica y Parinacota                        44                        48
# Tarapacá                                  77                        59
# Antofagasta                               90                        72
# Atacama                                   41                        67
# Coquimbo                                 143                        49
# Valparaíso                               434                        88
# RM                                     1.472                       529
# O’Higgins                                245                        95
# Maule                                    302                       234
# Ñuble                                    127                        42
# Biobío                                   506                       134
# Araucanía                                286                       140
# Los Ríos                                  73                        79
# Los Lagos                                144                        85
# Aysén                                      9                        27
# Magallanes                                43                        21
# Desconocida                                0                         0
# Total                                  4.039                     1.769
#
#                    Casos nuevos sin notificar * Casos activos confirmados **  \
# 0
# Arica y Parinacota                            4                          964
# Tarapacá                                      4                        1.138
# Antofagasta                                  15                        1.338
# Atacama                                       5                          895
# Coquimbo                                     10                        1.096
# Valparaíso                                   99                        4.482
# RM                                          277                       16.608
# O’Higgins                                     7                        2.314
# Maule                                        14                        3.856
# Ñuble                                         1                        1.095
# Biobío                                       35                        4.733
# Araucanía                                    76                        3.007
# Los Ríos                                      5                        1.443
# Los Lagos                                    11                        1.762
# Aysén                                         0                          170
# Magallanes                                    1                          390
# Desconocida                                   0                            0
# Total                                       564                       45.021
#
#                    Fallecidos totales *** Casos confirmados recuperados ****
# 0
# Arica y Parinacota                    363                             17.403
# Tarapacá                              567                             29.199
# Antofagasta                           909                             43.293
# Atacama                               182                             14.585
# Coquimbo                              560                             27.449
# Valparaíso                          2.059                             68.130
# RM                                 13.322                            423.089
# O’Higgins                             959                             39.350
# Maule                               1.073                             55.884
# Ñuble                                 429                             21.890
# Biobío                              1.719                             98.154
# Araucanía                             756                             57.394
# Los Ríos                              339                             28.645
# Los Lagos                             855                             61.826
# Aysén                                  29                              3.631
# Magallanes                            361                             22.936
# Desconocida                             1                                 46
# Total                              24.483                          1.012.904
